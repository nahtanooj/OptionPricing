# %%
# Import the calibration function
from data import Data

# %%
data = Data('^SPX')

# %%
data.save_heston_parameters()
# Out:
# Params: v0=0.04, kappa=2.0, theta=0.04, sigma=0.5, rho=-0.7, lambd=0.0
# Squared Error: 9.51646548255259e+50
# Params: v0=0.04000001, kappa=2.0, theta=0.04, sigma=0.5, rho=-0.7, lambd=0.0
# Squared Error: 9.51644139040997e+50
# Params: v0=0.04, kappa=2.00000001, theta=0.04, sigma=0.5, rho=-0.7, lambd=0.0
# Squared Error: 9.516471659196802e+50
# Params: v0=0.04, kappa=2.0, theta=0.04000001, sigma=0.5, rho=-0.7, lambd=0.0
# Squared Error: 9.516787936555788e+50
# Params: v0=0.04, kappa=2.0, theta=0.04, sigma=0.50000001, rho=-0.7, lambd=0.0
# Squared Error: 9.516442640013696e+50
# Params: v0=0.04, kappa=2.0, theta=0.04, sigma=0.5, rho=-0.6999999899999999, lambd=0.0
# Squared Error: 9.516480101496612e+50
# Params: v0=0.04, kappa=2.0, theta=0.04, sigma=0.5, rho=-0.7, lambd=1e-08
# Squared Error: 9.516465210212191e+50
# Params: v0=0.5, kappa=0.1, theta=0.001, sigma=2.0, rho=-1.0, lambd=1.0
# Squared Error: 203140.3554371565
# ...
